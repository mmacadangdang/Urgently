# %% [markdown]
# # Data Puller & Loader
# This file is meant to be used to pull data from the source API, and insert it into a SQL DB

# %%
# Import dependencies
import requests
import pandas as pd
import pprint as pp
from sqlalchemy import create_engine
from sqlalchemy import MetaData
from sqlalchemy import inspect
from sqlalchemy import Table
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.engine.url import URL

# %%
# Define the source data URL
url = 'https://data.sfgov.org/resource/vw6y-z8j6.json'
apiKey = '395ycd0srm44d3nzerame11px'
apiSecret = '1ltlkgjsl8z9rhjsu29znziitulgdrrloyasby6x5xt8c4ms0n'
appToken = 'Bqoj5KZHGKPOSgj7kePn5AqxT'
appSecret = 'o5hFFw0XlDMzC_vPlgzce6-lFMviuUJEEMhl'

# %%
# Define access details for the destination SQL server
# This server is hosted in Heroku
host = 'ec2-54-92-174-171.compute-1.amazonaws.com'
port = '5432'
database = 'd42onopn6vfl7k'
username = 'jczlpxqdwezmaz'
password = '4438996077085047be37272586fe9c58cb02ed30a9435682725fa90f3834d6a9'
uri = 'postgres://jczlpxqdwezmaz:4438996077085047be37272586fe9c58cb02ed30a9435682725fa90f3834d6a9@ec2-54-92-174-171.compute-1.amazonaws.com:5432/d42onopn6vfl7k'

# %%
# Get the data from the API
try:
    headers = {
            'Accept': 'application/json',
            'X-App-Token': appToken
            }
    response = requests.get(url, headers=headers)
except:
    print('Error')
else:
    print('Success!')
# Out:
# Success!

# %%
# Show the results of the API query
data = response.json()
pp.pprint(data)
# Out:
# [{'address': 'Not associated with a specific address',
#   'agency_responsible': 'SSP - MTA Feedback Queue',
#   'lat': '0E-12',
#   'long': '0E-12',
#   'point': {'human_address': '{"address": "", "city": "", "state": "", "zip": '
#                              '""}',
#             'latitude': '0.0',
#             'longitude': '0.0'},
#   'requested_datetime': '2020-02-03T00:52:26.000',
#   'service_details': '801_NextMuni_Technology',
#   'service_name': 'MUNI Feedback',
#   'service_request_id': '12030223',
#   'service_subtype': 'MUNI  - Services_Miscellaneous',
#   'source': 'Web',
#   'status_description': 'Open',
#   'status_notes': 'open',
#   'updated_datetime': '2020-02-03T01:15:12.000'},
#  {':@computed_region_26cr_cadq': '5',
#   ':@computed_region_6pnf_4xz7': '1',
#   ':@computed_region_6qbp_sg9q': '37',
#   ':@computed_region_ajp5_b2md': '20',
#   ':@computed_region_bh8s_q3mv': '28859',
#   ':@computed_region_f58d_8dbm': '19',
#   ':@computed_region_fyvs_ahh9': '19',
# ...
